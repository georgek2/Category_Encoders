# %%
import pandas as pd
import numpy as np

import lightgbm as lgb
import category_encoders as ce
from sklearn import metrics

# %%
data = pd.read_csv('kickstarter.csv', parse_dates=['launched'])
data.head(2)
# Out:
#            ID                                           name        category  \
# 0  1000002330                The Songs of Adelaide & Abullah          Poetry
# 1  1000003930  Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
#
#   main_category currency    deadline     goal            launched  pledged  \
# 0    Publishing      GBP  2015-10-09   1000.0 2015-08-11 12:12:28      0.0
# 1  Film & Video      USD  2017-11-01  30000.0 2017-09-02 04:43:57   2421.0
#
#     state  backers country  usd pledged  usd_pledged_real  usd_goal_real
# 0  failed        0      GB          0.0               0.0        1533.95
# 1  failed       15      US        100.0            2421.0       30000.00

# %%
data = data.query("state != 'live'")

# %%
data = data.assign(outcome=(data.state == 'successful').astype(int))
data.head(2)
# Out:
#            ID                                           name        category  \
# 0  1000002330                The Songs of Adelaide & Abullah          Poetry
# 1  1000003930  Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
#
#   main_category currency    deadline     goal            launched  pledged  \
# 0    Publishing      GBP  2015-10-09   1000.0 2015-08-11 12:12:28      0.0
# 1  Film & Video      USD  2017-11-01  30000.0 2017-09-02 04:43:57   2421.0
#
#     state  backers country  usd pledged  usd_pledged_real  usd_goal_real  \
# 0  failed        0      GB          0.0               0.0        1533.95
# 1  failed       15      US        100.0            2421.0       30000.00
#
#    outcome
# 0        0
# 1        0

# %%
cat_features = ['category', 'currency', 'country']

# %%
data = data.assign(hour=data.launched.dt.hour, 
                  day=data.launched.dt.day,
                  month=data.launched.dt.month,
                  year=data.launched.dt.year)

# %%
X = data[['hour', 'day', 'month', 'year', 'goal', 'outcome', 'category', 'currency', 'country']]
X.head(7)
# Out:
#    hour  day  month  year     goal  outcome        category currency country
# 0    12   11      8  2015   1000.0        0          Poetry      GBP      GB
# 1     4    2      9  2017  30000.0        0  Narrative Film      USD      US
# 2     0   12      1  2013  45000.0        0  Narrative Film      USD      US
# 3     3   17      3  2012   5000.0        0           Music      USD      US
# 4     8    4      7  2015  19500.0        0    Film & Video      USD      US
# 5    13   26      2  2016  50000.0        1     Restaurants      USD      US
# 6    18    1     12  2014   1000.0        1            Food      USD      US

# %%
valid_fraction = 0.1
valid_size = int(len(X) * valid_fraction)

train = X[:-2 * valid_size]
valid = X[-2 * valid_size: -valid_size]
test = X[-valid_size:]

valid.head(3)
# Out:
#         hour  day  month  year    goal  outcome     category currency country
# 302896    16   12      6  2015  5000.0        1  Documentary      USD      US
# 302897     1    8      7  2013  3700.0        1      Fiction      USD      US
# 302898    22   27      5  2014  5500.0        1        Music      GBP      GB

# %%
sub_tr = train.drop(cat_features, axis=1)
sub_va = valid.drop(cat_features, axis=1)
sub_te = test.drop(cat_features, axis=1)

# %%
encoder = ce.TargetEncoder(cols=cat_features)

# %%
encoder.fit(train[cat_features], train['outcome'])
# Out:
# TargetEncoder(cols=['category', 'currency', 'country'], drop_invariant=False,
#               handle_missing='value', handle_unknown='value',
#               min_samples_leaf=1, return_df=True, smoothing=1.0, verbose=0)

# %%
TE_train = sub_tr.join(encoder.transform(train[cat_features]).add_suffix('_target'))
TE_valid = sub_va.join(encoder.transform(valid[cat_features]).add_suffix('_target'))
TE_test = sub_te.join(encoder.transform(test[cat_features]).add_suffix('_target'))

TE_train.head()
# Out:
#    hour  day  month  year     goal  outcome  category_target  currency_target  \
# 0    12   11      8  2015   1000.0        0         0.360190         0.357122
# 1     4    2      9  2017  30000.0        0         0.384615         0.373392
# 2     0   12      1  2013  45000.0        0         0.384615         0.373392
# 3     3   17      3  2012   5000.0        0         0.412655         0.373392
# 4     8    4      7  2015  19500.0        0         0.302625         0.373392
#
#    country_target
# 0        0.361636
# 1        0.376631
# 2        0.376631
# 3        0.376631
# 4        0.376631

# %%
features = TE_train.columns.drop(['outcome'])
features
# Out:
# Index(['hour', 'day', 'month', 'year', 'goal', 'category_target',
#        'currency_target', 'country_target'],
#       dtype='object')

# %%
TE_train[features].head()
# Out:
#    hour  day  month  year     goal  category_target  currency_target  \
# 0    12   11      8  2015   1000.0         0.360190         0.357122
# 1     4    2      9  2017  30000.0         0.384615         0.373392
# 2     0   12      1  2013  45000.0         0.384615         0.373392
# 3     3   17      3  2012   5000.0         0.412655         0.373392
# 4     8    4      7  2015  19500.0         0.302625         0.373392
#
#    country_target
# 0        0.361636
# 1        0.376631
# 2        0.376631
# 3        0.376631
# 4        0.376631

# %%
dtrain = lgb.Dataset(TE_train[features], TE_train['outcome'])
dvalid = lgb.Dataset(TE_valid[features], TE_valid['outcome'])

dtrain

# %%
param = {'num_leaves': 65, 'objective': 'binary', 'metric': 'auc'}
num_rounds = 1000

# %%
model = lgb.train(param, dtrain, num_rounds, valid_sets=[dvalid], early_stopping_rounds=5)
# Out:
# [LightGBM] [Info] Number of positive: 107340, number of negative: 193350
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012027 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 528
# [LightGBM] [Info] Number of data points in the train set: 300690, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.356979 -> initscore=-0.588501
# [LightGBM] [Info] Start training from score -0.588501
# [1]	valid_0's auc: 0.723307
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's auc: 0.724935
# [3]	valid_0's auc: 0.72626
# [4]	valid_0's auc: 0.727261
# [5]	valid_0's auc: 0.729598
# [6]	valid_0's auc: 0.730533
# [7]	valid_0's auc: 0.730963
# [8]	valid_0's auc: 0.731206
# [9]	valid_0's auc: 0.731789
# [10]	valid_0's auc: 0.732178
# [11]	valid_0's auc: 0.732553
# [12]	valid_0's auc: 0.733249
# [13]	valid_0's auc: 0.733795
# [14]	valid_0's auc: 0.73402
# [15]	valid_0's auc: 0.734569
# [16]	valid_0's auc: 0.73488
# [17]	valid_0's auc: 0.735359
# [18]	valid_0's auc: 0.735633
# [19]	valid_0's auc: 0.735976
# [20]	valid_0's auc: 0.736418
# [21]	valid_0's auc: 0.736655
# [22]	valid_0's auc: 0.737037
# [23]	valid_0's auc: 0.737291
# [24]	valid_0's auc: 0.73767
# [25]	valid_0's auc: 0.737953
# [26]	valid_0's auc: 0.73821
# [27]	valid_0's auc: 0.738496
# [28]	valid_0's auc: 0.738876
# [29]	valid_0's auc: 0.739163
# [30]	valid_0's auc: 0.739322
# [31]	valid_0's auc: 0.739666
# [32]	valid_0's auc: 0.739875
# [33]	valid_0's auc: 0.740055
# [34]	valid_0's auc: 0.740297
# [35]	valid_0's auc: 0.740565
# [36]	valid_0's auc: 0.740729
# [37]	valid_0's auc: 0.741014
# [38]	valid_0's auc: 0.74121
# [39]	valid_0's auc: 0.741486
# [40]	valid_0's auc: 0.741658
# [41]	valid_0's auc: 0.741832
# [42]	valid_0's auc: 0.742061
# [43]	valid_0's auc: 0.742232
# [44]	valid_0's auc: 0.742432
# [45]	valid_0's auc: 0.742701
# [46]	valid_0's auc: 0.742787
# [47]	valid_0's auc: 0.742834
# [48]	valid_0's auc: 0.743038
# [49]	valid_0's auc: 0.743207
# [50]	valid_0's auc: 0.743378
# [51]	valid_0's auc: 0.74351
# [52]	valid_0's auc: 0.743549
# [53]	valid_0's auc: 0.74364
# [54]	valid_0's auc: 0.743722
# [55]	valid_0's auc: 0.74377
# [56]	valid_0's auc: 0.74393
# [57]	valid_0's auc: 0.743987
# [58]	valid_0's auc: 0.744146
# [59]	valid_0's auc: 0.744231
# [60]	valid_0's auc: 0.744361
# [61]	valid_0's auc: 0.744414
# [62]	valid_0's auc: 0.744491
# [63]	valid_0's auc: 0.744549
# [64]	valid_0's auc: 0.744529
# [65]	valid_0's auc: 0.744557
# [66]	valid_0's auc: 0.744626
# [67]	valid_0's auc: 0.744611
# [68]	valid_0's auc: 0.744719
# [69]	valid_0's auc: 0.74474
# [70]	valid_0's auc: 0.744774
# [71]	valid_0's auc: 0.744768
# [72]	valid_0's auc: 0.744935
# [73]	valid_0's auc: 0.74497
# [74]	valid_0's auc: 0.744988
# [75]	valid_0's auc: 0.745011
# [76]	valid_0's auc: 0.745041
# [77]	valid_0's auc: 0.745042
# [78]	valid_0's auc: 0.745092
# [79]	valid_0's auc: 0.745203
# [80]	valid_0's auc: 0.745211
# [81]	valid_0's auc: 0.745267
# [82]	valid_0's auc: 0.745258
# [83]	valid_0's auc: 0.745297
# [84]	valid_0's auc: 0.745359
# [85]	valid_0's auc: 0.745382
# [86]	valid_0's auc: 0.745361
# [87]	valid_0's auc: 0.745355
# [88]	valid_0's auc: 0.745386
# [89]	valid_0's auc: 0.745432
# [90]	valid_0's auc: 0.745437
# [91]	valid_0's auc: 0.745445
# [92]	valid_0's auc: 0.745563
# [93]	valid_0's auc: 0.745593
# [94]	valid_0's auc: 0.745674
# [95]	valid_0's auc: 0.74569
# [96]	valid_0's auc: 0.745693
# [97]	valid_0's auc: 0.745702
# [98]	valid_0's auc: 0.745755
# [99]	valid_0's auc: 0.745874
# [100]	valid_0's auc: 0.745892
# [101]	valid_0's auc: 0.745979
# [102]	valid_0's auc: 0.745984
# [103]	valid_0's auc: 0.745981
# [104]	valid_0's auc: 0.745982
# [105]	valid_0's auc: 0.746058
# [106]	valid_0's auc: 0.746076
# [107]	valid_0's auc: 0.746056
# [108]	valid_0's auc: 0.746095
# [109]	valid_0's auc: 0.746068
# [110]	valid_0's auc: 0.746063
# [111]	valid_0's auc: 0.746042
# [112]	valid_0's auc: 0.746055
# [113]	valid_0's auc: 0.746037
# Early stopping, best iteration is:
# [108]	valid_0's auc: 0.746095

# %%
preds = model.predict(TE_test[features])
score = metrics.roc_auc_score(TE_test['outcome'], preds)
score
# Out:
# 0.7452336045472924
